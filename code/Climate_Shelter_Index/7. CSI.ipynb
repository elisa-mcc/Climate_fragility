# %% [markdown]
# This script calculates the Climate Shelter Index for each public green area.
# A climate shelter should have these characteristics:
# - Surface area > 0.5 ha
# - NDVI > 0.4
# - Good accessibility
# - Presence of drinking fountains
# - Presence of  benches
# - Presence of picnic tables

# %% [markdown]
# ### 0. Libraries

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ### 1. Climate Shelter Index - CSI

# %%
# Load your shapefile
green_area = gpd.read_file(r'D:\Climate_Shelter_Index\isocrona\access_index')

# %%
green_area.head()
# Out:
#            quart                                   nome       ubicazione  \
# 0  Santo Stefano         PARCO DEI CALANCHI DI SABBIUNO  Via di Sabbiuno
# 1  Santo Stefano  GIARDINO MONUMENTO CADUTI DI SABBIUNO  Via di Sabbiuno
# 2  Santo Stefano         PARCO DEI CALANCHI DI SABBIUNO  Via di Sabbiuno
# 3  Santo Stefano                          PARCO PADERNO      Via Paderno
# 4  Santo Stefano                          PARCO PADERNO      Via Paderno
#
#         classe_uni classe_gia classe_pen          classe_suo  area_prato  \
# 0  PARCO ESTENSIVO  SOMMITALE     0 -20%  ARGILLOSO COMPATTO    9509.007
# 1            PARCO  SOMMITALE     0 -20%  ARGILLOSO COMPATTO    5514.205
# 2  PARCO ESTENSIVO  SOMMITALE     0 -20%  ARGILLOSO COMPATTO   16811.194
# 3  PARCO ESTENSIVO      PIANO   20 - 40%       MEDIO IMPASTO      87.272
# 4  PARCO ESTENSIVO      PIANO   20 - 40%       MEDIO IMPASTO      -4.817
#
#      area_ug    data_agg  ... benches id_bench      NDVI n_cycleway n_footway  \
# 0  12461.168  2009-01-29  ...      no      N/A  0.542155          0         0
# 1    6730.89  2009-01-29  ...      no      N/A  0.459359          0         0
# 2  24817.745  2007-03-13  ...      no      N/A  0.624308          0         0
# 3   6250.574  2007-09-20  ...      no      N/A  0.877684          0         8
# 4  21360.397  2007-09-20  ...      no      N/A  0.879811          0         8
#
#   busstop5 busstop10 disab_p_5 access_ind  \
# 0        2         3        -1   0.012821
# 1        0         0        -1   0.000000
# 2        2         3        -1   0.012821
# 3        3         8        -1   0.071077
# 4        3         8        -1   0.071077
#
#                                             geometry
# 0  POLYGON ((11.31509 44.42248, 11.31511 44.42256...
# 1  POLYGON ((11.31288 44.42104, 11.31289 44.42109...
# 2  POLYGON ((11.31463 44.42146, 11.31496 44.42149...
# 3  POLYGON ((11.32362 44.45097, 11.32372 44.45110...
# 4  POLYGON ((11.32160 44.45340, 11.32164 44.45341...
#
# [5 rows x 34 columns]

# %%
green_area.columns
# Out:
# Index(['quart', 'nome', 'ubicazione', 'classe_uni', 'classe_gia', 'classe_pen',
#        'classe_suo', 'area_prato', 'area_ug', 'data_agg', 'siepi', 'bosco',
#        'arboreo', 'arbustivo', 'pavim', 'idro', 'quartiere', 'area_stati',
#        'zona_pross', 'area_Ha', 'd_fountain', 'id_df', 'picnic_tab', 'id_pt',
#        'benches', 'id_bench', 'NDVI', 'n_cycleway', 'n_footway', 'busstop5',
#        'busstop10', 'disab_p_5', 'access_ind', 'geometry'],
#       dtype='object')

# %%
# Define weights for each characteristic (surface area, NDVI, accessibility, drinking fountains, benches, picnic tables)
weights = {
    'surface_area': 0.25,
    'NDVI': 0.25,
    'accessibility': 0.2,
    'drinking_fountains': 0.1,
    'benches': 0.1,
    'picnic_tables': 0.1
}

# %%
# Count variables for presence of drinking fountains, benches, and picnic tables
green_area['n_df'] = green_area['id_df'].apply(lambda x: len(x.split(',')) if x != 'N/A' else 0)
green_area['n_bench'] = green_area['id_bench'].apply(lambda x: len(x.split(',')) if x != 'N/A' else 0)
green_area['n_pt'] = green_area['id_pt'].apply(lambda x: len(x.split(',')) if x != 'N/A' else 0)

# %%
# Define the columns you want to normalize
columns_to_normalize = ['n_df', 'n_bench', 'n_pt']

# Perform min-max normalization for each column
for col_name in columns_to_normalize:
    min_value = green_area[col_name].min()
    max_value = green_area[col_name].max()
    green_area[col_name] = (green_area[col_name] - min_value) / (max_value - min_value)

# %%
# Normalize surface area (0.5 ha threshold)
green_area['norm_area'] = green_area['area_Ha'].apply(lambda x: 1 if x >= 0.5 else 0)

# %%
# Normalize NDVI (0.4 threshold)
green_area['norm_NDVI'] = green_area['NDVI'].apply(lambda x: x if x >= 0.4 else 0)

# %%
# Calculate the CSI based on the weighted and normalized variables
green_area['CSI'] = (
    weights['surface_area'] * green_area['norm_area'] +
    weights['NDVI'] * green_area['norm_NDVI'] +
    weights['accessibility'] * green_area['access_ind'] +
    weights['drinking_fountains'] * green_area['n_df'] +
    weights['benches'] * green_area['n_bench'] +
    weights['picnic_tables'] * green_area['n_pt']
)

# %%
green_area = green_area.drop(columns=['n_df', 'n_bench', 'n_pt', 'norm_area', 'norm_NDVI'])

# %%
green_area[green_area['NDVI']<0.41].head()
# Out:
#                      quart                         nome          ubicazione  \
# 220  Borgo Panigale - Reno         GIARDINO TERESA NOCE  Via del Beccaccino
# 311      Porto - Saragozza         SCUOLA MEDIA GANDINO        Via Graziano
# 317      Porto - Saragozza  SCUOLA ELEM. TERESINA GUIDI          Via Calori
# 330          Santo Stefano    GIARDINO LEGNANI PIZZARDI    Via del Cane 3/b
# 332          Santo Stefano    GIARDINO LEGNANI PIZZARDI    Via del Cane 3/b
#
#            classe_uni classe_gia classe_pen          classe_suo  area_prato  \
# 220          GIARDINO      PIANO        NaN  ARGILLOSO COMPATTO       0.114
# 311  VERDE SCOLASTICO      PIANO     0 -20%  ARGILLOSO COMPATTO      55.935
# 317  VERDE SCOLASTICO      PIANO     0 -20%  ARGILLOSO COMPATTO      30.760
# 330          GIARDINO      PIANO     0 -20%       MEDIO IMPASTO       3.783
# 332          GIARDINO      PIANO     0 -20%       MEDIO IMPASTO       3.480
#
#      area_ug    data_agg  ... id_bench      NDVI n_cycleway n_footway  \
# 220  239.302  2015-06-10  ...      N/A  0.398521          0         5
# 311   55.935  2006-06-06  ...      N/A  0.388157          0         0
# 317    30.76  2006-06-06  ...      N/A  0.378452          0         0
# 330    7.242  2009-10-20  ...      N/A  0.351903          0         0
# 332    6.502  2009-10-20  ...      N/A  0.365648          0         0
#
#     busstop5 busstop10 disab_p_5 access_ind  \
# 220        9        34        22   0.125866
# 311        0         0        -1   0.000000
# 317        7        38        40   0.102983
# 330        0         0        -1   0.000000
# 332        0         0        -1   0.000000
#
#                                               geometry       CSI
# 220  POLYGON ((11.29106 44.49354, 11.29112 44.49352...  0.025173
# 311  POLYGON ((11.33103 44.50035, 11.33104 44.50038...  0.000000
# 317  POLYGON ((11.33043 44.50045, 11.33043 44.50046...  0.020597
# 330  POLYGON ((11.34252 44.49087, 11.34252 44.49086...  0.000000
# 332  POLYGON ((11.34255 44.49084, 11.34256 44.49085...  0.000000
#
# [5 rows x 35 columns]

# %%
green_area.to_file(r'D:\Climate_Shelter_Index\isocrona\CSI')

# %% [markdown]
# #### 1.2 CSI for selected areas

# %%
csi = gpd.read_file(r'D:\Climate_Shelter_Index\isocrona\CSI')
covered_areas = gpd.read_file(r"D:\Meteoblue\covered_areas.shp")

# %%
# select only green area within covered areas
covered_areas_csi =csi[csi.geometry.within(covered_areas.unary_union)]

# %%
covered_areas_csi.columns
# Out:
# Index(['quart', 'nome', 'ubicazione', 'classe_uni', 'classe_gia', 'classe_pen',
#        'classe_suo', 'area_prato', 'area_ug', 'data_agg', 'siepi', 'bosco',
#        'arboreo', 'arbustivo', 'pavim', 'idro', 'quartiere', 'area_stati',
#        'zona_pross', 'area_Ha', 'd_fountain', 'id_df', 'picnic_tab', 'id_pt',
#        'benches', 'id_bench', 'NDVI', 'n_cycleway', 'n_footway', 'busstop5',
#        'busstop10', 'disab_p_5', 'access_ind', 'CSI', 'geometry'],
#       dtype='object')

# %%
covered_areas_csi_sorted = covered_areas_csi.sort_values(by='CSI', ascending=False).head(10)

# %%
for index, row in covered_areas_csi_sorted.iterrows():
    print(f"{row['nome']}, with CSI of {round(row['CSI'],3)}")
# Out:
# PARCO DELLA MONTAGNOLA, with CSI of 0.849
# GIARDINO CENTRO CIVICO SAN DONATO (EX BENTIVOGLI E MARCINELLE), with CSI of 0.733
# PARCO NICHOLAS GREEN ( EX  VILLA CONTRI), with CSI of 0.695
# P.CO LUNETTA GAMBERINI, with CSI of 0.694
# PARCO DI VILLA ANGELETTI, with CSI of 0.689
# GIARDINI MARGHERITA, with CSI of 0.669
# PARCO 11 SETTEMBRE 2001 (EX AREA EX MANIFATTURA TABACCHI), with CSI of 0.636
# PERCORSO LUNGONAVILE, with CSI of 0.575
# CENTRO SPORTIVO CAVINA, with CSI of 0.525
# GIARDINO DEL GHISELLO (EX GIARDINO CALDA), with CSI of 0.503

# %%
covered_areas_csi_sorted
# Out:
#                        quart  \
# 488            Santo Stefano
# 427  San Donato - San Vitale
# 185    Borgo Panigale - Reno
# 835            Santo Stefano
# 502                   Navile
# 874            Santo Stefano
# 322        Porto - Saragozza
# 527                   Navile
# 62     Borgo Panigale - Reno
# 242    Borgo Panigale - Reno
#
#                                                   nome  \
# 488                             PARCO DELLA MONTAGNOLA
# 427  GIARDINO CENTRO CIVICO SAN DONATO (EX BENTIVOG...
# 185           PARCO NICHOLAS GREEN ( EX  VILLA CONTRI)
# 835                             P.CO LUNETTA GAMBERINI
# 502                           PARCO DI VILLA ANGELETTI
# 874                                GIARDINI MARGHERITA
# 322  PARCO 11 SETTEMBRE 2001 (EX AREA EX MANIFATTUR...
# 527                               PERCORSO LUNGONAVILE
# 62                              CENTRO SPORTIVO CAVINA
# 242          GIARDINO DEL GHISELLO (EX GIARDINO CALDA)
#
#                                      ubicazione      classe_uni classe_gia  \
# 488                          Piazza VIII Agosto           PARCO      PIANO
# 427                   Piazza Giovanni Spadolini           PARCO      PIANO
# 185                           Via della Certosa           PARCO      PIANO
# 835  Via degli Orti 60, Largo Lercaro, Via Nadi           PARCO      PIANO
# 502                                Via Carracci           PARCO      PIANO
# 874                            Viale Gozzardini           PARCO      PIANO
# 322                                Via Rivareno           PARCO      PIANO
# 527        Via Yuri Gagarin - Via dei Terraioli           PARCO      PIANO
# 62                              via Biancolelli  VERDE SPORTIVO      PIANO
# 242                                  via Treves        GIARDINO      PIANO
#
#     classe_pen          classe_suo  area_prato     area_ug    data_agg  ...  \
# 488     0 -20%       MEDIO IMPASTO   28445.649   51876.635  2023-02-08  ...
# 427     0 -20%       MEDIO IMPASTO    9446.168   16567.977  2010-07-23  ...
# 185     0 -20%       MEDIO IMPASTO   50456.763   58927.621  2020-09-29  ...
# 835     0 -20%  ARGILLOSO COMPATTO   64346.153    81519.19  2022-03-23  ...
# 502     0 -20%  ARGILLOSO COMPATTO   59536.660   89013.989  2007-05-08  ...
# 874     0 -20%       MEDIO IMPASTO  149344.335  203169.402  2007-03-14  ...
# 322     0 -20%       MEDIO IMPASTO   10772.264   14073.304  2006-06-11  ...
# 527     0 -20%       MEDIO IMPASTO    8205.678   10826.838  2007-09-13  ...
# 62      0 -20%       MEDIO IMPASTO   12697.181    17690.31  2005-08-22  ...
# 242        NaN  ARGILLOSO COMPATTO    5036.162    5797.385  2015-04-15  ...
#
#                                               id_bench      NDVI n_cycleway  \
# 488  11093356755,11093356866,11093356865,9137608683...  0.723216          0
# 427  11093642583,11093642585,11093642584,1109364254...  0.651157          1
# 185  10896934099,10896934098,3180723125,3180723124,...  0.684428         10
# 835  10676938409,10676938435,10676938434,1067693843...  0.669272         18
# 502  1653184518,1653184559,1653184550,1653184647,16...  0.770084         11
# 874  6328825142,8990334463,8990334458,8990334459,89...  0.690379          0
# 322  11107786706,11107772107,11107772108,1110778860...  0.682335          0
# 527                                          469864580  0.756890         39
# 62   6316104034,6316104033,6316108901,6316105837,63...  0.705562          0
# 242  11032970081,11032970075,11032970072,1103297007...  0.758808          4
#
#     n_footway busstop5 busstop10 disab_p_5 access_ind       CSI  \
# 488        50       42        69        82   0.632287  0.849095
# 427        12       12        45        22   0.201932  0.732509
# 185        14       10        41        10   0.261080  0.695323
# 835        10       19        51       146   0.444982  0.693981
# 502         4       13        45        19   0.233576  0.689236
# 874        10       25        63        32   0.270727  0.668574
# 322         0       14        61        68   0.180638  0.636378
# 527        19       26        91        29   0.658218  0.575033
# 62          8        2        12        23   0.087037  0.525465
# 242         8       16        32        32   0.212574  0.503050
#
#                                               geometry
# 488  MULTIPOLYGON (((11.34654 44.50371, 11.34658 44...
# 427  POLYGON ((11.36568 44.50428, 11.36583 44.50436...
# 185  POLYGON ((11.30137 44.49696, 11.30138 44.49699...
# 835  POLYGON ((11.37171 44.48198, 11.37261 44.48164...
# 502  POLYGON ((11.33405 44.51449, 11.33406 44.51430...
# 874  MULTIPOLYGON (((11.35401 44.48366, 11.35402 44...
# 322  POLYGON ((11.33618 44.50023, 11.33630 44.50023...
# 527  POLYGON ((11.33525 44.52143, 11.33525 44.52143...
# 62   POLYGON ((11.26946 44.52346, 11.26947 44.52346...
# 242  POLYGON ((11.29746 44.49094, 11.29746 44.49094...
#
# [10 rows x 35 columns]

# %%
covered_areas_csi.to_file(r'D:\Climate_Shelter_Index\CSI_covered_areas')

# %% [markdown]
# ##### 1.2.1 Green Surface > 0.5

# %%
covered_areas_csi[covered_areas_csi['area_Ha']>0.5].shape
# Out:
# (181, 35)

# %%
# find the top 10 parks with the largest surface area
covered_areas_csi_sorted_2 = covered_areas_csi.sort_values(by='area_Ha', ascending=False).head(10)

# %%
for index, row in covered_areas_csi_sorted_2.iterrows():
    print(f"{row['nome']}, with a green area of {round(row['area_Ha'], 3)} hectares")
# Out:
# GIARDINI MARGHERITA, with a green area of 14.934 hectares
# LUNGO RENO CHIARINI BERTOCCHI, with a green area of 8.194 hectares
# PARCO VINCENZO TANARA, with a green area of 6.644 hectares
# P.CO LUNETTA GAMBERINI, with a green area of 6.435 hectares
# PARCO BADEN POWELL, with a green area of 6.123 hectares
# PARCO DI VILLA ANGELETTI, with a green area of 5.954 hectares
# PARCO DELLE QUERCE, with a green area of 5.446 hectares
# PARCO NICHOLAS GREEN ( EX  VILLA CONTRI), with a green area of 5.046 hectares
# LUNGORENO PONTE BACCHELLI - PONENTE, with a green area of 4.755 hectares
# LUNGORENO TRATTO TRIUMVIRATO, with a green area of 4.412 hectares

# %% [markdown]
# ##### 1.2.2 NDVI > 0.4

# %%
covered_areas_csi[covered_areas_csi['NDVI']>0.4].shape
# Out:
# (702, 35)

# %% [markdown]
# ##### 1.2.3 NDVI + Green Surface

# %%
covered_areas_csi[(covered_areas_csi['NDVI']>0.4) & (covered_areas_csi['area_Ha']>0.5)].shape
# Out:
# (181, 35)
